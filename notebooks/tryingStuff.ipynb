# %%
from EMS_env import EMS_env

# %%
ems_env = EMS_env()
# Out:
# C:\Users\wenap\.conda\envs\PPO_project\lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
ems_env.reset()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ems_env.reset()
#
# File ~\PycharmProjects\PPO_project\EMS_env.py:133, in EMS_env.reset(self, seed, options)
#     130 def reset(self, seed=None, options=None):
#     131     self.start_index = np.random.randint(1, self.L - self.n_steps - 1)
# --> 133     self.V_1_ref = self.V_r_1_all[self.start_index,:]
#     134     self.V_2_ref = self.V_r_2_all[self.start_index,:]
#     135     self.Vt = self.np_random.uniform(low=-self.Vt_min, high=self.Vt_max, size=1)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
